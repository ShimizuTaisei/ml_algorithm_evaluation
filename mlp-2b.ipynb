# %% [markdown]
# # MLP-2b
# - Dataset: EMNIST ByClass
# - Model: MLP (2 hidden layer, (256, 128) units, Sigmoid, Dropout 0.2)
# - Batch Size: 2048
# - Output Layer: 62 classes
# - Accuracy

# %%
import tensorflow_datasets as tfds
import tensorflow as tf
import matplotlib.pyplot as plt
import csv

# %%
# Load the dataset
(ds_train, ds_test), ds_info = tfds.load(
    'emnist/byclass',
    split=['train', 'test'],
    shuffle_files=True,
    as_supervised=True,
    with_info=True
)

# ds = tfds.load('mnist', split='train', shuffle_files=True)

def preprocess(image, label):
    image = tf.cast(image, tf.float32) / 255.0  # Normalize to [0, 1]
    image = tf.reshape(image, [-1])
    return image, label

BATCH_SIZE = 2048
ds_train = ds_train.map(preprocess).shuffle(10000).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
ds_test = ds_test.map(preprocess).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
# Out:
# 2025-07-14 01:27:04.207621: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4 Max
# 2025-07-14 01:27:04.207641: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 36.00 GB
# 2025-07-14 01:27:04.207646: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 13.50 GB
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1752424024.207657  296706 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1752424024.207671  296706 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=(28 * 28,)),
    tf.keras.layers.Dense(256, activation='sigmoid'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation='sigmoid'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(62, activation='softmax')  # 62 classes for EMNIST ByClass
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)
# Out:
# /Users/shimizutaisei/miniforge3/envs/tensorflow/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %%
history = model.fit(ds_train, epochs=50, validation_data=ds_test)

test_loss, test_accuracy = model.evaluate(ds_test)
print(f'Test accuracy: {test_accuracy:.4f}')
# Out:
# Epoch 1/50
# 2025-07-14 01:27:04.510063: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 2025-07-14 01:27:04.643147: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:387] The default buffer size is 262144, which is overridden by the user specified `buffer_size` of 8388608
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - accuracy: 0.3517 - loss: 2.7536 - val_accuracy: 0.6705 - val_loss: 1.1779
# Epoch 2/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.6662 - loss: 1.1822 - val_accuracy: 0.7410 - val_loss: 0.8599
# Epoch 3/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.7260 - loss: 0.9233 - val_accuracy: 0.7762 - val_loss: 0.7176
# Epoch 4/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.7549 - loss: 0.8022 - val_accuracy: 0.7946 - val_loss: 0.6432
# Epoch 5/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.7714 - loss: 0.7327 - val_accuracy: 0.8050 - val_loss: 0.5969
# Epoch 6/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.7832 - loss: 0.6854 - val_accuracy: 0.8130 - val_loss: 0.5661
# Epoch 7/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.7908 - loss: 0.6532 - val_accuracy: 0.8180 - val_loss: 0.5449
# Epoch 8/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.7961 - loss: 0.6302 - val_accuracy: 0.8220 - val_loss: 0.5279
# Epoch 9/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8003 - loss: 0.6107 - val_accuracy: 0.8253 - val_loss: 0.5142
# Epoch 10/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8050 - loss: 0.5951 - val_accuracy: 0.8287 - val_loss: 0.5027
# Epoch 11/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8080 - loss: 0.5826 - val_accuracy: 0.8308 - val_loss: 0.4943
# Epoch 12/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8104 - loss: 0.5717 - val_accuracy: 0.8323 - val_loss: 0.4866
# Epoch 13/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8131 - loss: 0.5628 - val_accuracy: 0.8343 - val_loss: 0.4802
# Epoch 14/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8143 - loss: 0.5542 - val_accuracy: 0.8356 - val_loss: 0.4739
# Epoch 15/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8168 - loss: 0.5458 - val_accuracy: 0.8370 - val_loss: 0.4692
# Epoch 16/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8182 - loss: 0.5407 - val_accuracy: 0.8381 - val_loss: 0.4653
# Epoch 17/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8200 - loss: 0.5339 - val_accuracy: 0.8392 - val_loss: 0.4613
# Epoch 18/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8212 - loss: 0.5298 - val_accuracy: 0.8402 - val_loss: 0.4578
# Epoch 19/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8223 - loss: 0.5257 - val_accuracy: 0.8411 - val_loss: 0.4546
# Epoch 20/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - accuracy: 0.8234 - loss: 0.5210 - val_accuracy: 0.8419 - val_loss: 0.4518
# Epoch 21/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8243 - loss: 0.5180 - val_accuracy: 0.8424 - val_loss: 0.4488
# Epoch 22/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8254 - loss: 0.5144 - val_accuracy: 0.8431 - val_loss: 0.4464
# Epoch 23/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8260 - loss: 0.5097 - val_accuracy: 0.8438 - val_loss: 0.4440
# Epoch 24/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - accuracy: 0.8276 - loss: 0.5064 - val_accuracy: 0.8445 - val_loss: 0.4419
# Epoch 25/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8277 - loss: 0.5043 - val_accuracy: 0.8446 - val_loss: 0.4404
# Epoch 26/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8280 - loss: 0.5016 - val_accuracy: 0.8449 - val_loss: 0.4383
# Epoch 27/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8284 - loss: 0.4990 - val_accuracy: 0.8452 - val_loss: 0.4364
# Epoch 28/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8297 - loss: 0.4971 - val_accuracy: 0.8459 - val_loss: 0.4355
# Epoch 29/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - accuracy: 0.8296 - loss: 0.4950 - val_accuracy: 0.8463 - val_loss: 0.4341
# Epoch 30/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8309 - loss: 0.4917 - val_accuracy: 0.8467 - val_loss: 0.4323
# Epoch 31/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8312 - loss: 0.4903 - val_accuracy: 0.8471 - val_loss: 0.4308
# Epoch 32/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8316 - loss: 0.4890 - val_accuracy: 0.8477 - val_loss: 0.4298
# Epoch 33/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8322 - loss: 0.4858 - val_accuracy: 0.8473 - val_loss: 0.4294
# Epoch 34/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8328 - loss: 0.4851 - val_accuracy: 0.8486 - val_loss: 0.4276
# Epoch 35/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8331 - loss: 0.4819 - val_accuracy: 0.8484 - val_loss: 0.4269
# Epoch 36/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8337 - loss: 0.4803 - val_accuracy: 0.8487 - val_loss: 0.4260
# Epoch 37/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8342 - loss: 0.4796 - val_accuracy: 0.8492 - val_loss: 0.4256
# Epoch 38/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8345 - loss: 0.4774 - val_accuracy: 0.8494 - val_loss: 0.4244
# Epoch 39/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8347 - loss: 0.4773 - val_accuracy: 0.8495 - val_loss: 0.4234
# Epoch 40/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8351 - loss: 0.4752 - val_accuracy: 0.8497 - val_loss: 0.4225
# Epoch 41/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8353 - loss: 0.4741 - val_accuracy: 0.8498 - val_loss: 0.4221
# Epoch 42/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8355 - loss: 0.4735 - val_accuracy: 0.8497 - val_loss: 0.4221
# Epoch 43/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8355 - loss: 0.4720 - val_accuracy: 0.8505 - val_loss: 0.4205
# Epoch 44/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8366 - loss: 0.4708 - val_accuracy: 0.8501 - val_loss: 0.4193
# Epoch 45/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8363 - loss: 0.4699 - val_accuracy: 0.8505 - val_loss: 0.4197
# Epoch 46/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8368 - loss: 0.4678 - val_accuracy: 0.8508 - val_loss: 0.4179
# Epoch 47/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8372 - loss: 0.4674 - val_accuracy: 0.8510 - val_loss: 0.4176
# Epoch 48/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8372 - loss: 0.4666 - val_accuracy: 0.8510 - val_loss: 0.4176
# Epoch 49/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8379 - loss: 0.4648 - val_accuracy: 0.8513 - val_loss: 0.4171
# Epoch 50/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8375 - loss: 0.4655 - val_accuracy: 0.8510 - val_loss: 0.4166
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8514 - loss: 0.4138
# Test accuracy: 0.8510

# %%
train_loss = history.history['loss']
train_accuracy = history.history['accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_accuracy']

epochs = range(1, len(train_loss) + 1)

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, 'b-', label='Training Loss')
plt.plot(epochs, val_loss, 'r-', label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %%
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracy, 'b-', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r-', label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

# %%
output_file = "mlp-2b.csv"
with open(output_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Epoch", "Train Loss", "Train Accuracy", "Validation Loss", "Validation Accuracy"])
    for epoch in epochs:
        writer.writerow([
            epoch,
            train_loss[epoch - 1],
            train_accuracy[epoch - 1],
            val_loss[epoch - 1],
            val_accuracy[epoch - 1]
        ])

print(f"Training results saved to {output_file}")
# Out:
# Training results saved to mlp-2b.csv
