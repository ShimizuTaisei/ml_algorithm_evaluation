# %% [markdown]
# # MLP-3b
# - Dataset: EMNIST ByClass
# - Model: MLP (3 hidden layer, (512, 256, 128) units, sigmoid, Dropout 0.2)
# - Batch Size: 2048
# - Output Layer: 62 classes
# - Accuracy

# %%
import tensorflow_datasets as tfds
import tensorflow as tf
import matplotlib.pyplot as plt
import csv

# %%
# Load the dataset
(ds_train, ds_test), ds_info = tfds.load(
    'emnist/byclass',
    split=['train', 'test'],
    shuffle_files=True,
    as_supervised=True,
    with_info=True
)

# ds = tfds.load('mnist', split='train', shuffle_files=True)

def preprocess(image, label):
    image = tf.cast(image, tf.float32) / 255.0  # Normalize to [0, 1]
    image = tf.reshape(image, [-1])
    return image, label

BATCH_SIZE = 2048
ds_train = ds_train.map(preprocess).shuffle(10000).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
ds_test = ds_test.map(preprocess).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
# Out:
# 2025-07-14 02:21:34.384654: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4 Max
# 2025-07-14 02:21:34.384676: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 36.00 GB
# 2025-07-14 02:21:34.384682: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 13.50 GB
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1752427294.384693  389718 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1752427294.384709  389718 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=(28 * 28,)),
    tf.keras.layers.Dense(512, activation='sigmoid'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(256, activation='sigmoid'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation='sigmoid'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(62, activation='softmax')  # 62 classes for EMNIST ByClass
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)
# Out:
# /Users/shimizutaisei/miniforge3/envs/tensorflow/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %%
history = model.fit(ds_train, epochs=50, validation_data=ds_test)

test_loss, test_accuracy = model.evaluate(ds_test)
print(f'Test accuracy: {test_accuracy:.4f}')
# Out:
# Epoch 1/50
# 2025-07-14 02:21:34.738445: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 2025-07-14 02:21:34.910362: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:387] The default buffer size is 262144, which is overridden by the user specified `buffer_size` of 8388608
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - accuracy: 0.2836 - loss: 2.9356 - val_accuracy: 0.6898 - val_loss: 1.0842
# Epoch 2/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.6929 - loss: 1.0721 - val_accuracy: 0.7718 - val_loss: 0.7325
# Epoch 3/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.7551 - loss: 0.8015 - val_accuracy: 0.7986 - val_loss: 0.6208
# Epoch 4/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.7804 - loss: 0.6981 - val_accuracy: 0.8129 - val_loss: 0.5636
# Epoch 5/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.7949 - loss: 0.6411 - val_accuracy: 0.8210 - val_loss: 0.5292
# Epoch 6/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8038 - loss: 0.6035 - val_accuracy: 0.8274 - val_loss: 0.5058
# Epoch 7/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8096 - loss: 0.5785 - val_accuracy: 0.8319 - val_loss: 0.4888
# Epoch 8/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8154 - loss: 0.5565 - val_accuracy: 0.8353 - val_loss: 0.4746
# Epoch 9/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8190 - loss: 0.5404 - val_accuracy: 0.8379 - val_loss: 0.4644
# Epoch 10/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8226 - loss: 0.5263 - val_accuracy: 0.8408 - val_loss: 0.4544
# Epoch 11/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8254 - loss: 0.5153 - val_accuracy: 0.8428 - val_loss: 0.4472
# Epoch 12/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8287 - loss: 0.5029 - val_accuracy: 0.8441 - val_loss: 0.4405
# Epoch 13/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8303 - loss: 0.4964 - val_accuracy: 0.8452 - val_loss: 0.4349
# Epoch 14/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8320 - loss: 0.4887 - val_accuracy: 0.8465 - val_loss: 0.4309
# Epoch 15/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8338 - loss: 0.4819 - val_accuracy: 0.8483 - val_loss: 0.4261
# Epoch 16/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8351 - loss: 0.4757 - val_accuracy: 0.8494 - val_loss: 0.4220
# Epoch 17/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8377 - loss: 0.4683 - val_accuracy: 0.8500 - val_loss: 0.4183
# Epoch 18/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8384 - loss: 0.4641 - val_accuracy: 0.8510 - val_loss: 0.4148
# Epoch 19/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8395 - loss: 0.4600 - val_accuracy: 0.8510 - val_loss: 0.4129
# Epoch 20/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8406 - loss: 0.4552 - val_accuracy: 0.8518 - val_loss: 0.4102
# Epoch 21/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8418 - loss: 0.4513 - val_accuracy: 0.8526 - val_loss: 0.4083
# Epoch 22/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8423 - loss: 0.4484 - val_accuracy: 0.8531 - val_loss: 0.4065
# Epoch 23/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - accuracy: 0.8435 - loss: 0.4436 - val_accuracy: 0.8536 - val_loss: 0.4046
# Epoch 24/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8434 - loss: 0.4419 - val_accuracy: 0.8543 - val_loss: 0.4023
# Epoch 25/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8453 - loss: 0.4383 - val_accuracy: 0.8547 - val_loss: 0.4015
# Epoch 26/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8461 - loss: 0.4347 - val_accuracy: 0.8554 - val_loss: 0.3990
# Epoch 27/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8467 - loss: 0.4319 - val_accuracy: 0.8552 - val_loss: 0.3988
# Epoch 28/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - accuracy: 0.8475 - loss: 0.4294 - val_accuracy: 0.8555 - val_loss: 0.3970
# Epoch 29/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8483 - loss: 0.4263 - val_accuracy: 0.8560 - val_loss: 0.3956
# Epoch 30/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8491 - loss: 0.4250 - val_accuracy: 0.8562 - val_loss: 0.3949
# Epoch 31/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8489 - loss: 0.4225 - val_accuracy: 0.8564 - val_loss: 0.3939
# Epoch 32/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8493 - loss: 0.4210 - val_accuracy: 0.8569 - val_loss: 0.3927
# Epoch 33/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8501 - loss: 0.4187 - val_accuracy: 0.8575 - val_loss: 0.3910
# Epoch 34/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8506 - loss: 0.4165 - val_accuracy: 0.8572 - val_loss: 0.3916
# Epoch 35/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8511 - loss: 0.4144 - val_accuracy: 0.8577 - val_loss: 0.3904
# Epoch 36/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8519 - loss: 0.4125 - val_accuracy: 0.8578 - val_loss: 0.3898
# Epoch 37/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8519 - loss: 0.4112 - val_accuracy: 0.8579 - val_loss: 0.3891
# Epoch 38/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8523 - loss: 0.4101 - val_accuracy: 0.8583 - val_loss: 0.3877
# Epoch 39/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8529 - loss: 0.4084 - val_accuracy: 0.8588 - val_loss: 0.3871
# Epoch 40/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8534 - loss: 0.4052 - val_accuracy: 0.8589 - val_loss: 0.3868
# Epoch 41/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8533 - loss: 0.4056 - val_accuracy: 0.8593 - val_loss: 0.3858
# Epoch 42/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8543 - loss: 0.4032 - val_accuracy: 0.8598 - val_loss: 0.3856
# Epoch 43/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8545 - loss: 0.4021 - val_accuracy: 0.8591 - val_loss: 0.3854
# Epoch 44/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8547 - loss: 0.4020 - val_accuracy: 0.8597 - val_loss: 0.3843
# Epoch 45/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8553 - loss: 0.3993 - val_accuracy: 0.8596 - val_loss: 0.3843
# Epoch 46/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8555 - loss: 0.3992 - val_accuracy: 0.8597 - val_loss: 0.3834
# Epoch 47/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8560 - loss: 0.3980 - val_accuracy: 0.8602 - val_loss: 0.3832
# Epoch 48/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8557 - loss: 0.3969 - val_accuracy: 0.8599 - val_loss: 0.3830
# Epoch 49/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8566 - loss: 0.3946 - val_accuracy: 0.8601 - val_loss: 0.3820
# Epoch 50/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8555 - loss: 0.3949 - val_accuracy: 0.8603 - val_loss: 0.3818
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8607 - loss: 0.3800
# Test accuracy: 0.8603

# %%
train_loss = history.history['loss']
train_accuracy = history.history['accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_accuracy']

epochs = range(1, len(train_loss) + 1)

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, 'b-', label='Training Loss')
plt.plot(epochs, val_loss, 'r-', label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %%
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracy, 'b-', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r-', label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

# %%
output_file = "mlp-3b.csv"
with open(output_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Epoch", "Train Loss", "Train Accuracy", "Validation Loss", "Validation Accuracy"])
    for epoch in epochs:
        writer.writerow([
            epoch,
            train_loss[epoch - 1],
            train_accuracy[epoch - 1],
            val_loss[epoch - 1],
            val_accuracy[epoch - 1]
        ])

print(f"Training results saved to {output_file}")
# Out:
# Training results saved to mlp-3b.csv
