# %% [markdown]
# # MLP-1a
# - Dataset: EMNIST ByClass
# - Model: MLP (1 hidden layer, 128 units, ELU, Dropout 0.2)
# - Batch Size: 2048
# - Output Layer: 62 classes
# - Accuracy

# %%
import tensorflow_datasets as tfds
import tensorflow as tf
import matplotlib.pyplot as plt
import csv

# %%
# Load the dataset
(ds_train, ds_test), ds_info = tfds.load(
    'emnist/byclass',
    split=['train', 'test'],
    shuffle_files=True,
    as_supervised=True,
    with_info=True
)

# ds = tfds.load('mnist', split='train', shuffle_files=True)

def preprocess(image, label):
    image = tf.cast(image, tf.float32) / 255.0  # Normalize to [0, 1]
    image = tf.reshape(image, [-1])
    return image, label

BATCH_SIZE = 2048
ds_train = ds_train.map(preprocess).shuffle(10000).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
ds_test = ds_test.map(preprocess).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(28 * 28,)),
    tf.keras.layers.Dense(128, activation='elu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(62, activation='softmax'),
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

# %%
history = model.fit(ds_train, epochs=50, validation_data=ds_test)

test_loss, test_accuracy = model.evaluate(ds_test)
print(f'Test accuracy: {test_accuracy:.4f}')
# Out:
# Epoch 1/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.5267 - loss: 1.9101 - val_accuracy: 0.7307 - val_loss: 0.9393
# Epoch 2/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7205 - loss: 0.9681 - val_accuracy: 0.7721 - val_loss: 0.7602
# Epoch 3/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7552 - loss: 0.8195 - val_accuracy: 0.7924 - val_loss: 0.6700
# Epoch 4/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7718 - loss: 0.7450 - val_accuracy: 0.8035 - val_loss: 0.6189
# Epoch 5/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7822 - loss: 0.6965 - val_accuracy: 0.8121 - val_loss: 0.5850
# Epoch 6/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7894 - loss: 0.6656 - val_accuracy: 0.8182 - val_loss: 0.5621
# Epoch 7/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7946 - loss: 0.6427 - val_accuracy: 0.8215 - val_loss: 0.5438
# Epoch 8/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7990 - loss: 0.6246 - val_accuracy: 0.8236 - val_loss: 0.5332
# Epoch 9/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8026 - loss: 0.6124 - val_accuracy: 0.8276 - val_loss: 0.5213
# Epoch 10/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8049 - loss: 0.6002 - val_accuracy: 0.8288 - val_loss: 0.5142
# Epoch 11/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8074 - loss: 0.5914 - val_accuracy: 0.8301 - val_loss: 0.5069
# Epoch 12/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.8092 - loss: 0.5825 - val_accuracy: 0.8312 - val_loss: 0.5013
# Epoch 13/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8106 - loss: 0.5766 - val_accuracy: 0.8333 - val_loss: 0.4963
# Epoch 14/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8122 - loss: 0.5702 - val_accuracy: 0.8337 - val_loss: 0.4933
# Epoch 15/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.8135 - loss: 0.5657 - val_accuracy: 0.8339 - val_loss: 0.4894
# Epoch 16/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8146 - loss: 0.5607 - val_accuracy: 0.8350 - val_loss: 0.4858
# Epoch 17/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8145 - loss: 0.5572 - val_accuracy: 0.8358 - val_loss: 0.4829
# Epoch 18/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8163 - loss: 0.5530 - val_accuracy: 0.8363 - val_loss: 0.4811
# Epoch 19/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8170 - loss: 0.5498 - val_accuracy: 0.8372 - val_loss: 0.4798
# Epoch 20/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8171 - loss: 0.5482 - val_accuracy: 0.8367 - val_loss: 0.4781
# Epoch 21/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8183 - loss: 0.5452 - val_accuracy: 0.8375 - val_loss: 0.4759
# Epoch 22/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8193 - loss: 0.5429 - val_accuracy: 0.8377 - val_loss: 0.4738
# Epoch 23/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8194 - loss: 0.5408 - val_accuracy: 0.8385 - val_loss: 0.4726
# Epoch 24/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8202 - loss: 0.5361 - val_accuracy: 0.8387 - val_loss: 0.4719
# Epoch 25/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8200 - loss: 0.5368 - val_accuracy: 0.8402 - val_loss: 0.4692
# Epoch 26/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8211 - loss: 0.5334 - val_accuracy: 0.8397 - val_loss: 0.4686
# Epoch 27/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8216 - loss: 0.5326 - val_accuracy: 0.8402 - val_loss: 0.4667
# Epoch 28/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8219 - loss: 0.5318 - val_accuracy: 0.8403 - val_loss: 0.4662
# Epoch 29/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8225 - loss: 0.5284 - val_accuracy: 0.8406 - val_loss: 0.4654
# Epoch 30/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8226 - loss: 0.5276 - val_accuracy: 0.8408 - val_loss: 0.4647
# Epoch 31/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8234 - loss: 0.5261 - val_accuracy: 0.8412 - val_loss: 0.4637
# Epoch 32/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.8233 - loss: 0.5253 - val_accuracy: 0.8408 - val_loss: 0.4643
# Epoch 33/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8234 - loss: 0.5245 - val_accuracy: 0.8404 - val_loss: 0.4640
# Epoch 34/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8236 - loss: 0.5237 - val_accuracy: 0.8414 - val_loss: 0.4617
# Epoch 35/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.8235 - loss: 0.5241 - val_accuracy: 0.8411 - val_loss: 0.4624
# Epoch 36/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8242 - loss: 0.5208 - val_accuracy: 0.8416 - val_loss: 0.4613
# Epoch 37/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8244 - loss: 0.5195 - val_accuracy: 0.8417 - val_loss: 0.4606
# Epoch 38/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8249 - loss: 0.5186 - val_accuracy: 0.8416 - val_loss: 0.4601
# Epoch 39/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8253 - loss: 0.5173 - val_accuracy: 0.8415 - val_loss: 0.4603
# Epoch 40/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8258 - loss: 0.5170 - val_accuracy: 0.8409 - val_loss: 0.4604
# Epoch 41/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8251 - loss: 0.5172 - val_accuracy: 0.8421 - val_loss: 0.4584
# Epoch 42/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8258 - loss: 0.5154 - val_accuracy: 0.8414 - val_loss: 0.4592
# Epoch 43/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.8260 - loss: 0.5150 - val_accuracy: 0.8415 - val_loss: 0.4584
# Epoch 44/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8264 - loss: 0.5130 - val_accuracy: 0.8416 - val_loss: 0.4578
# Epoch 45/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8261 - loss: 0.5139 - val_accuracy: 0.8417 - val_loss: 0.4574
# Epoch 46/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8268 - loss: 0.5124 - val_accuracy: 0.8425 - val_loss: 0.4568
# Epoch 47/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8265 - loss: 0.5126 - val_accuracy: 0.8420 - val_loss: 0.4569
# Epoch 48/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8269 - loss: 0.5124 - val_accuracy: 0.8421 - val_loss: 0.4560
# Epoch 49/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8271 - loss: 0.5103 - val_accuracy: 0.8423 - val_loss: 0.4557
# Epoch 50/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8267 - loss: 0.5107 - val_accuracy: 0.8422 - val_loss: 0.4561
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.8423 - loss: 0.4540
# Test accuracy: 0.8422

# %%
train_loss = history.history['loss']
train_accuracy = history.history['accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_accuracy']

epochs = range(1, len(train_loss) + 1)

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, 'b-', label='Training Loss')
plt.plot(epochs, val_loss, 'r-', label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %%
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracy, 'b-', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r-', label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

# %%
output_file = "mlp-1a.csv"
with open(output_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Epoch", "Train Loss", "Train Accuracy", "Validation Loss", "Validation Accuracy"])
    for epoch in epochs:
        writer.writerow([
            epoch,
            train_loss[epoch - 1],
            train_accuracy[epoch - 1],
            val_loss[epoch - 1],
            val_accuracy[epoch - 1]
        ])

print(f"Training results saved to {output_file}")
# Out:
# Training results saved to mlp-1a.csv
