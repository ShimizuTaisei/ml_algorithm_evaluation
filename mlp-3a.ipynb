# %% [markdown]
# # MLP-3a
# - Dataset: EMNIST ByClass
# - Model: MLP (3 hidden layer, (512, 256, 128) units, elu, Dropout 0.2)
# - Batch Size: 2048
# - Output Layer: 62 classes
# - Accuracy

# %%
import tensorflow_datasets as tfds
import tensorflow as tf
import matplotlib.pyplot as plt
import csv

# %%
# Load the dataset
(ds_train, ds_test), ds_info = tfds.load(
    'emnist/byclass',
    split=['train', 'test'],
    shuffle_files=True,
    as_supervised=True,
    with_info=True
)

# ds = tfds.load('mnist', split='train', shuffle_files=True)

def preprocess(image, label):
    image = tf.cast(image, tf.float32) / 255.0  # Normalize to [0, 1]
    image = tf.reshape(image, [-1])
    return image, label

BATCH_SIZE = 2048
ds_train = ds_train.map(preprocess).shuffle(10000).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
ds_test = ds_test.map(preprocess).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
# Out:
# 2025-07-14 01:39:50.552773: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4 Max
# 2025-07-14 01:39:50.552795: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 36.00 GB
# 2025-07-14 01:39:50.552801: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 13.50 GB
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1752424790.552811  327016 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1752424790.552827  327016 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=(28 * 28,)),
    tf.keras.layers.Dense(512, activation='elu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(256, activation='elu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation='elu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(62, activation='softmax')  # 62 classes for EMNIST ByClass
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)
# Out:
# /Users/shimizutaisei/miniforge3/envs/tensorflow/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %%
history = model.fit(ds_train, epochs=50, validation_data=ds_test)

test_loss, test_accuracy = model.evaluate(ds_test)
print(f'Test accuracy: {test_accuracy:.4f}')
# Out:
# Epoch 1/50
# 2025-07-14 01:39:50.896957: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 2025-07-14 01:39:51.063745: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:387] The default buffer size is 262144, which is overridden by the user specified `buffer_size` of 8388608
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 15s 40ms/step - accuracy: 0.5925 - loss: 1.5503 - val_accuracy: 0.7979 - val_loss: 0.6206
# Epoch 2/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.7721 - loss: 0.7163 - val_accuracy: 0.8236 - val_loss: 0.5207
# Epoch 3/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - accuracy: 0.7985 - loss: 0.6145 - val_accuracy: 0.8342 - val_loss: 0.4825
# Epoch 4/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8095 - loss: 0.5695 - val_accuracy: 0.8397 - val_loss: 0.4599
# Epoch 5/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8182 - loss: 0.5391 - val_accuracy: 0.8436 - val_loss: 0.4448
# Epoch 6/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8225 - loss: 0.5196 - val_accuracy: 0.8461 - val_loss: 0.4347
# Epoch 7/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8271 - loss: 0.5044 - val_accuracy: 0.8484 - val_loss: 0.4285
# Epoch 8/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8303 - loss: 0.4925 - val_accuracy: 0.8514 - val_loss: 0.4179
# Epoch 9/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8327 - loss: 0.4829 - val_accuracy: 0.8516 - val_loss: 0.4141
# Epoch 10/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8348 - loss: 0.4735 - val_accuracy: 0.8525 - val_loss: 0.4089
# Epoch 11/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8370 - loss: 0.4672 - val_accuracy: 0.8533 - val_loss: 0.4063
# Epoch 12/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8386 - loss: 0.4598 - val_accuracy: 0.8554 - val_loss: 0.4016
# Epoch 13/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8397 - loss: 0.4543 - val_accuracy: 0.8563 - val_loss: 0.3973
# Epoch 14/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8408 - loss: 0.4500 - val_accuracy: 0.8564 - val_loss: 0.3965
# Epoch 15/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8425 - loss: 0.4458 - val_accuracy: 0.8576 - val_loss: 0.3936
# Epoch 16/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8437 - loss: 0.4406 - val_accuracy: 0.8575 - val_loss: 0.3920
# Epoch 17/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8446 - loss: 0.4365 - val_accuracy: 0.8578 - val_loss: 0.3916
# Epoch 18/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8452 - loss: 0.4339 - val_accuracy: 0.8587 - val_loss: 0.3892
# Epoch 19/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8460 - loss: 0.4310 - val_accuracy: 0.8592 - val_loss: 0.3869
# Epoch 20/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8470 - loss: 0.4271 - val_accuracy: 0.8584 - val_loss: 0.3870
# Epoch 21/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8477 - loss: 0.4249 - val_accuracy: 0.8596 - val_loss: 0.3847
# Epoch 22/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8482 - loss: 0.4220 - val_accuracy: 0.8596 - val_loss: 0.3839
# Epoch 23/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8483 - loss: 0.4207 - val_accuracy: 0.8602 - val_loss: 0.3823
# Epoch 24/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8502 - loss: 0.4172 - val_accuracy: 0.8588 - val_loss: 0.3830
# Epoch 25/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8497 - loss: 0.4152 - val_accuracy: 0.8599 - val_loss: 0.3811
# Epoch 26/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8504 - loss: 0.4137 - val_accuracy: 0.8607 - val_loss: 0.3800
# Epoch 27/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8509 - loss: 0.4130 - val_accuracy: 0.8612 - val_loss: 0.3793
# Epoch 28/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8511 - loss: 0.4092 - val_accuracy: 0.8612 - val_loss: 0.3779
# Epoch 29/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8524 - loss: 0.4075 - val_accuracy: 0.8608 - val_loss: 0.3788
# Epoch 30/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8527 - loss: 0.4067 - val_accuracy: 0.8611 - val_loss: 0.3765
# Epoch 31/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8525 - loss: 0.4055 - val_accuracy: 0.8609 - val_loss: 0.3768
# Epoch 32/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8534 - loss: 0.4031 - val_accuracy: 0.8615 - val_loss: 0.3757
# Epoch 33/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8535 - loss: 0.4021 - val_accuracy: 0.8619 - val_loss: 0.3754
# Epoch 34/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8544 - loss: 0.4008 - val_accuracy: 0.8619 - val_loss: 0.3755
# Epoch 35/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8544 - loss: 0.3984 - val_accuracy: 0.8623 - val_loss: 0.3750
# Epoch 36/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8548 - loss: 0.3980 - val_accuracy: 0.8615 - val_loss: 0.3766
# Epoch 37/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8553 - loss: 0.3963 - val_accuracy: 0.8619 - val_loss: 0.3765
# Epoch 38/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8553 - loss: 0.3949 - val_accuracy: 0.8621 - val_loss: 0.3742
# Epoch 39/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8555 - loss: 0.3958 - val_accuracy: 0.8622 - val_loss: 0.3739
# Epoch 40/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8550 - loss: 0.3941 - val_accuracy: 0.8615 - val_loss: 0.3764
# Epoch 41/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8562 - loss: 0.3922 - val_accuracy: 0.8626 - val_loss: 0.3722
# Epoch 42/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8562 - loss: 0.3930 - val_accuracy: 0.8621 - val_loss: 0.3727
# Epoch 43/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8559 - loss: 0.3923 - val_accuracy: 0.8632 - val_loss: 0.3731
# Epoch 44/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8569 - loss: 0.3899 - val_accuracy: 0.8629 - val_loss: 0.3713
# Epoch 45/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8567 - loss: 0.3893 - val_accuracy: 0.8630 - val_loss: 0.3722
# Epoch 46/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8574 - loss: 0.3885 - val_accuracy: 0.8631 - val_loss: 0.3717
# Epoch 47/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - accuracy: 0.8579 - loss: 0.3874 - val_accuracy: 0.8632 - val_loss: 0.3708
# Epoch 48/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8573 - loss: 0.3874 - val_accuracy: 0.8634 - val_loss: 0.3709
# Epoch 49/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8582 - loss: 0.3856 - val_accuracy: 0.8636 - val_loss: 0.3712
# Epoch 50/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8586 - loss: 0.3852 - val_accuracy: 0.8637 - val_loss: 0.3702
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8644 - loss: 0.3689
# Test accuracy: 0.8637

# %%
train_loss = history.history['loss']
train_accuracy = history.history['accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_accuracy']

epochs = range(1, len(train_loss) + 1)

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, 'b-', label='Training Loss')
plt.plot(epochs, val_loss, 'r-', label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %%
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracy, 'b-', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r-', label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

# %%
output_file = "mlp-3a.csv"
with open(output_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Epoch", "Train Loss", "Train Accuracy", "Validation Loss", "Validation Accuracy"])
    for epoch in epochs:
        writer.writerow([
            epoch,
            train_loss[epoch - 1],
            train_accuracy[epoch - 1],
            val_loss[epoch - 1],
            val_accuracy[epoch - 1]
        ])

print(f"Training results saved to {output_file}")
# Out:
# Training results saved to mlp-3a.csv
