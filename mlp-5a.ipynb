# %% [markdown]
# # MLP-5a
# - Dataset: EMNIST ByClass
# - Model: MLP (5 hidden layer, (1024, 512, 256, 128, 64) units, elu, Dropout 0.2)
# - Batch Size: 2048
# - Output Layer: 62 classes
# - Accuracy

# %%
import tensorflow_datasets as tfds
import tensorflow as tf
import matplotlib.pyplot as plt
import csv

# %%
# Load the dataset
(ds_train, ds_test), ds_info = tfds.load(
    'emnist/byclass',
    split=['train', 'test'],
    shuffle_files=True,
    as_supervised=True,
    with_info=True
)

# ds = tfds.load('mnist', split='train', shuffle_files=True)

def preprocess(image, label):
    image = tf.cast(image, tf.float32) / 255.0  # Normalize to [0, 1]
    image = tf.reshape(image, [-1])
    return image, label

BATCH_SIZE = 2048
ds_train = ds_train.map(preprocess).shuffle(10000).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
ds_test = ds_test.map(preprocess).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
# Out:
# 2025-07-14 03:10:35.959909: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4 Max
# 2025-07-14 03:10:35.959930: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 36.00 GB
# 2025-07-14 03:10:35.959937: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 13.50 GB
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1752430235.959947  501404 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1752430235.959963  501404 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=(28 * 28,)),
    tf.keras.layers.Dense(1024, activation='elu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(512, activation='elu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(256, activation='elu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation='elu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(64, activation='elu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(62, activation='softmax')  # 62 classes for EMNIST ByClass
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)
# Out:
# /Users/shimizutaisei/miniforge3/envs/tensorflow/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %%
history = model.fit(ds_train, epochs=50, validation_data=ds_test)

test_loss, test_accuracy = model.evaluate(ds_test)
print(f'Test accuracy: {test_accuracy:.4f}')
# Out:
# Epoch 1/50
# 2025-07-14 03:10:36.706268: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 2025-07-14 03:10:36.947663: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:387] The default buffer size is 262144, which is overridden by the user specified `buffer_size` of 8388608
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 17s 42ms/step - accuracy: 0.5787 - loss: 1.6271 - val_accuracy: 0.8083 - val_loss: 0.5784
# Epoch 2/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7763 - loss: 0.7038 - val_accuracy: 0.8295 - val_loss: 0.4925
# Epoch 3/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8024 - loss: 0.6030 - val_accuracy: 0.8380 - val_loss: 0.4625
# Epoch 4/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8141 - loss: 0.5560 - val_accuracy: 0.8429 - val_loss: 0.4442
# Epoch 5/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8223 - loss: 0.5247 - val_accuracy: 0.8462 - val_loss: 0.4324
# Epoch 6/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8288 - loss: 0.5041 - val_accuracy: 0.8496 - val_loss: 0.4198
# Epoch 7/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8335 - loss: 0.4871 - val_accuracy: 0.8518 - val_loss: 0.4125
# Epoch 8/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8358 - loss: 0.4759 - val_accuracy: 0.8527 - val_loss: 0.4086
# Epoch 9/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8389 - loss: 0.4650 - val_accuracy: 0.8549 - val_loss: 0.4040
# Epoch 10/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 42ms/step - accuracy: 0.8410 - loss: 0.4561 - val_accuracy: 0.8553 - val_loss: 0.4002
# Epoch 11/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 23s 68ms/step - accuracy: 0.8433 - loss: 0.4492 - val_accuracy: 0.8558 - val_loss: 0.3981
# Epoch 12/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 24s 68ms/step - accuracy: 0.8453 - loss: 0.4437 - val_accuracy: 0.8572 - val_loss: 0.3940
# Epoch 13/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 23s 67ms/step - accuracy: 0.8463 - loss: 0.4362 - val_accuracy: 0.8581 - val_loss: 0.3910
# Epoch 14/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 23s 67ms/step - accuracy: 0.8475 - loss: 0.4327 - val_accuracy: 0.8593 - val_loss: 0.3887
# Epoch 15/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 24s 71ms/step - accuracy: 0.8486 - loss: 0.4267 - val_accuracy: 0.8601 - val_loss: 0.3881
# Epoch 16/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 24s 70ms/step - accuracy: 0.8505 - loss: 0.4221 - val_accuracy: 0.8596 - val_loss: 0.3871
# Epoch 17/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 24s 69ms/step - accuracy: 0.8513 - loss: 0.4189 - val_accuracy: 0.8609 - val_loss: 0.3828
# Epoch 18/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 24s 70ms/step - accuracy: 0.8518 - loss: 0.4157 - val_accuracy: 0.8613 - val_loss: 0.3841
# Epoch 19/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 23s 66ms/step - accuracy: 0.8530 - loss: 0.4117 - val_accuracy: 0.8607 - val_loss: 0.3827
# Epoch 20/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 24s 68ms/step - accuracy: 0.8534 - loss: 0.4090 - val_accuracy: 0.8620 - val_loss: 0.3801
# Epoch 21/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 24s 70ms/step - accuracy: 0.8552 - loss: 0.4042 - val_accuracy: 0.8627 - val_loss: 0.3797
# Epoch 22/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 24s 69ms/step - accuracy: 0.8552 - loss: 0.4022 - val_accuracy: 0.8623 - val_loss: 0.3815
# Epoch 23/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 24s 70ms/step - accuracy: 0.8563 - loss: 0.3997 - val_accuracy: 0.8629 - val_loss: 0.3789
# Epoch 24/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 24s 68ms/step - accuracy: 0.8570 - loss: 0.3972 - val_accuracy: 0.8631 - val_loss: 0.3784
# Epoch 25/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 24s 71ms/step - accuracy: 0.8573 - loss: 0.3953 - val_accuracy: 0.8625 - val_loss: 0.3789
# Epoch 26/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 24s 70ms/step - accuracy: 0.8582 - loss: 0.3918 - val_accuracy: 0.8621 - val_loss: 0.3775
# Epoch 27/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 23s 67ms/step - accuracy: 0.8582 - loss: 0.3916 - val_accuracy: 0.8637 - val_loss: 0.3784
# Epoch 28/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 25s 72ms/step - accuracy: 0.8591 - loss: 0.3895 - val_accuracy: 0.8639 - val_loss: 0.3765
# Epoch 29/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 23s 67ms/step - accuracy: 0.8593 - loss: 0.3879 - val_accuracy: 0.8644 - val_loss: 0.3754
# Epoch 30/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 24s 70ms/step - accuracy: 0.8598 - loss: 0.3857 - val_accuracy: 0.8640 - val_loss: 0.3755
# Epoch 31/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 25s 71ms/step - accuracy: 0.8609 - loss: 0.3834 - val_accuracy: 0.8648 - val_loss: 0.3729
# Epoch 32/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 24s 70ms/step - accuracy: 0.8614 - loss: 0.3815 - val_accuracy: 0.8643 - val_loss: 0.3746
# Epoch 33/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 23s 68ms/step - accuracy: 0.8618 - loss: 0.3794 - val_accuracy: 0.8646 - val_loss: 0.3755
# Epoch 34/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 23s 68ms/step - accuracy: 0.8626 - loss: 0.3770 - val_accuracy: 0.8640 - val_loss: 0.3761
# Epoch 35/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 24s 71ms/step - accuracy: 0.8618 - loss: 0.3776 - val_accuracy: 0.8646 - val_loss: 0.3774
# Epoch 36/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 24s 68ms/step - accuracy: 0.8627 - loss: 0.3757 - val_accuracy: 0.8646 - val_loss: 0.3741
# Epoch 37/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 25s 72ms/step - accuracy: 0.8637 - loss: 0.3727 - val_accuracy: 0.8652 - val_loss: 0.3751
# Epoch 38/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 24s 68ms/step - accuracy: 0.8634 - loss: 0.3734 - val_accuracy: 0.8650 - val_loss: 0.3758
# Epoch 39/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 24s 69ms/step - accuracy: 0.8634 - loss: 0.3718 - val_accuracy: 0.8653 - val_loss: 0.3747
# Epoch 40/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 23s 65ms/step - accuracy: 0.8644 - loss: 0.3706 - val_accuracy: 0.8645 - val_loss: 0.3779
# Epoch 41/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 24s 69ms/step - accuracy: 0.8641 - loss: 0.3694 - val_accuracy: 0.8647 - val_loss: 0.3742
# Epoch 42/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 23s 68ms/step - accuracy: 0.8646 - loss: 0.3683 - val_accuracy: 0.8658 - val_loss: 0.3748
# Epoch 43/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 23s 68ms/step - accuracy: 0.8653 - loss: 0.3666 - val_accuracy: 0.8659 - val_loss: 0.3743
# Epoch 44/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 23s 66ms/step - accuracy: 0.8656 - loss: 0.3658 - val_accuracy: 0.8658 - val_loss: 0.3737
# Epoch 45/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 24s 71ms/step - accuracy: 0.8658 - loss: 0.3651 - val_accuracy: 0.8664 - val_loss: 0.3728
# Epoch 46/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 23s 68ms/step - accuracy: 0.8660 - loss: 0.3639 - val_accuracy: 0.8662 - val_loss: 0.3741
# Epoch 47/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 23s 66ms/step - accuracy: 0.8667 - loss: 0.3621 - val_accuracy: 0.8657 - val_loss: 0.3753
# Epoch 48/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 24s 71ms/step - accuracy: 0.8664 - loss: 0.3615 - val_accuracy: 0.8663 - val_loss: 0.3747
# Epoch 49/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 23s 67ms/step - accuracy: 0.8669 - loss: 0.3601 - val_accuracy: 0.8658 - val_loss: 0.3738
# Epoch 50/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 24s 69ms/step - accuracy: 0.8670 - loss: 0.3598 - val_accuracy: 0.8658 - val_loss: 0.3735
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.8666 - loss: 0.3718
# Test accuracy: 0.8658

# %%
train_loss = history.history['loss']
train_accuracy = history.history['accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_accuracy']

epochs = range(1, len(train_loss) + 1)

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, 'b-', label='Training Loss')
plt.plot(epochs, val_loss, 'r-', label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %%
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracy, 'b-', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r-', label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

# %%
output_file = "mlp-5a.csv"
with open(output_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Epoch", "Train Loss", "Train Accuracy", "Validation Loss", "Validation Accuracy"])
    for epoch in epochs:
        writer.writerow([
            epoch,
            train_loss[epoch - 1],
            train_accuracy[epoch - 1],
            val_loss[epoch - 1],
            val_accuracy[epoch - 1]
        ])

print(f"Training results saved to {output_file}")
# Out:
# Training results saved to mlp-5a.csv
