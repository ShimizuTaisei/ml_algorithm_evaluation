# %% [markdown]
# # MLP-2a
# - Dataset: EMNIST ByClass
# - Model: MLP (2 hidden layer, (256, 128) units, ELU, Dropout 0.2)
# - Batch Size: 2048
# - Output Layer: 62 classes
# - Accuracy

# %%
import tensorflow_datasets as tfds
import tensorflow as tf
import matplotlib.pyplot as plt
import csv

# %%
# Load the dataset
(ds_train, ds_test), ds_info = tfds.load(
    'emnist/byclass',
    split=['train', 'test'],
    shuffle_files=True,
    as_supervised=True,
    with_info=True
)

# ds = tfds.load('mnist', split='train', shuffle_files=True)

def preprocess(image, label):
    image = tf.cast(image, tf.float32) / 255.0  # Normalize to [0, 1]
    image = tf.reshape(image, [-1])
    return image, label

BATCH_SIZE = 2048
ds_train = ds_train.map(preprocess).shuffle(10000).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
ds_test = ds_test.map(preprocess).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
# Out:
# 2025-07-14 01:13:39.051143: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4 Max
# 2025-07-14 01:13:39.051163: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 36.00 GB
# 2025-07-14 01:13:39.051168: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 13.50 GB
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1752423219.051177  265071 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1752423219.051192  265071 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=(28 * 28,)),
    tf.keras.layers.Dense(256, activation='elu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation='elu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(62, activation='softmax')  # 62 classes for EMNIST ByClass
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)
# Out:
# /Users/shimizutaisei/miniforge3/envs/tensorflow/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %%
history = model.fit(ds_train, epochs=50, validation_data=ds_test)

test_loss, test_accuracy = model.evaluate(ds_test)
print(f'Test accuracy: {test_accuracy:.4f}')
# Out:
# Epoch 1/50
# 2025-07-14 01:13:39.346964: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 2025-07-14 01:13:39.479602: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:387] The default buffer size is 262144, which is overridden by the user specified `buffer_size` of 8388608
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - accuracy: 0.5646 - loss: 1.6908 - val_accuracy: 0.7763 - val_loss: 0.7306
# Epoch 2/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.7538 - loss: 0.8047 - val_accuracy: 0.8081 - val_loss: 0.5896
# Epoch 3/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.7834 - loss: 0.6807 - val_accuracy: 0.8207 - val_loss: 0.5362
# Epoch 4/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.7971 - loss: 0.6243 - val_accuracy: 0.8285 - val_loss: 0.5056
# Epoch 5/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8058 - loss: 0.5901 - val_accuracy: 0.8336 - val_loss: 0.4865
# Epoch 6/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8109 - loss: 0.5693 - val_accuracy: 0.8368 - val_loss: 0.4721
# Epoch 7/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8149 - loss: 0.5532 - val_accuracy: 0.8395 - val_loss: 0.4608
# Epoch 8/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8190 - loss: 0.5377 - val_accuracy: 0.8418 - val_loss: 0.4532
# Epoch 9/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8213 - loss: 0.5293 - val_accuracy: 0.8427 - val_loss: 0.4486
# Epoch 10/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8235 - loss: 0.5194 - val_accuracy: 0.8447 - val_loss: 0.4426
# Epoch 11/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8256 - loss: 0.5131 - val_accuracy: 0.8459 - val_loss: 0.4382
# Epoch 12/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8272 - loss: 0.5076 - val_accuracy: 0.8466 - val_loss: 0.4325
# Epoch 13/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8281 - loss: 0.5016 - val_accuracy: 0.8475 - val_loss: 0.4295
# Epoch 14/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8303 - loss: 0.4958 - val_accuracy: 0.8486 - val_loss: 0.4280
# Epoch 15/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8313 - loss: 0.4916 - val_accuracy: 0.8491 - val_loss: 0.4248
# Epoch 16/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8314 - loss: 0.4879 - val_accuracy: 0.8506 - val_loss: 0.4201
# Epoch 17/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8333 - loss: 0.4842 - val_accuracy: 0.8509 - val_loss: 0.4196
# Epoch 18/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8335 - loss: 0.4796 - val_accuracy: 0.8513 - val_loss: 0.4161
# Epoch 19/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8341 - loss: 0.4779 - val_accuracy: 0.8513 - val_loss: 0.4173
# Epoch 20/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8354 - loss: 0.4748 - val_accuracy: 0.8524 - val_loss: 0.4142
# Epoch 21/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8358 - loss: 0.4723 - val_accuracy: 0.8520 - val_loss: 0.4133
# Epoch 22/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8368 - loss: 0.4689 - val_accuracy: 0.8533 - val_loss: 0.4100
# Epoch 23/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8372 - loss: 0.4675 - val_accuracy: 0.8529 - val_loss: 0.4106
# Epoch 24/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8371 - loss: 0.4650 - val_accuracy: 0.8536 - val_loss: 0.4080
# Epoch 25/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8383 - loss: 0.4637 - val_accuracy: 0.8543 - val_loss: 0.4077
# Epoch 26/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8383 - loss: 0.4617 - val_accuracy: 0.8545 - val_loss: 0.4060
# Epoch 27/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8392 - loss: 0.4593 - val_accuracy: 0.8546 - val_loss: 0.4050
# Epoch 28/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8391 - loss: 0.4579 - val_accuracy: 0.8550 - val_loss: 0.4038
# Epoch 29/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8395 - loss: 0.4554 - val_accuracy: 0.8549 - val_loss: 0.4039
# Epoch 30/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8406 - loss: 0.4535 - val_accuracy: 0.8558 - val_loss: 0.4006
# Epoch 31/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8409 - loss: 0.4518 - val_accuracy: 0.8556 - val_loss: 0.4013
# Epoch 32/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8406 - loss: 0.4528 - val_accuracy: 0.8560 - val_loss: 0.3999
# Epoch 33/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8412 - loss: 0.4510 - val_accuracy: 0.8559 - val_loss: 0.3997
# Epoch 34/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8416 - loss: 0.4499 - val_accuracy: 0.8564 - val_loss: 0.3996
# Epoch 35/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8424 - loss: 0.4481 - val_accuracy: 0.8565 - val_loss: 0.3982
# Epoch 36/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8424 - loss: 0.4470 - val_accuracy: 0.8563 - val_loss: 0.3981
# Epoch 37/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8424 - loss: 0.4459 - val_accuracy: 0.8572 - val_loss: 0.3960
# Epoch 38/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8427 - loss: 0.4438 - val_accuracy: 0.8565 - val_loss: 0.3971
# Epoch 39/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8424 - loss: 0.4448 - val_accuracy: 0.8572 - val_loss: 0.3956
# Epoch 40/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8432 - loss: 0.4427 - val_accuracy: 0.8573 - val_loss: 0.3949
# Epoch 41/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8432 - loss: 0.4413 - val_accuracy: 0.8571 - val_loss: 0.3944
# Epoch 42/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8439 - loss: 0.4407 - val_accuracy: 0.8572 - val_loss: 0.3949
# Epoch 43/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8442 - loss: 0.4395 - val_accuracy: 0.8571 - val_loss: 0.3943
# Epoch 44/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8436 - loss: 0.4397 - val_accuracy: 0.8566 - val_loss: 0.3950
# Epoch 45/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8443 - loss: 0.4381 - val_accuracy: 0.8568 - val_loss: 0.3942
# Epoch 46/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.8441 - loss: 0.4380 - val_accuracy: 0.8573 - val_loss: 0.3940
# Epoch 47/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8446 - loss: 0.4371 - val_accuracy: 0.8573 - val_loss: 0.3926
# Epoch 48/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8452 - loss: 0.4355 - val_accuracy: 0.8572 - val_loss: 0.3929
# Epoch 49/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8455 - loss: 0.4352 - val_accuracy: 0.8579 - val_loss: 0.3919
# Epoch 50/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.8456 - loss: 0.4333 - val_accuracy: 0.8579 - val_loss: 0.3919
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8570 - loss: 0.3904
# Test accuracy: 0.8579

# %%
train_loss = history.history['loss']
train_accuracy = history.history['accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_accuracy']

epochs = range(1, len(train_loss) + 1)

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, 'b-', label='Training Loss')
plt.plot(epochs, val_loss, 'r-', label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %%
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracy, 'b-', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r-', label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

# %%
output_file = "mlp-2a.csv"
with open(output_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Epoch", "Train Loss", "Train Accuracy", "Validation Loss", "Validation Accuracy"])
    for epoch in epochs:
        writer.writerow([
            epoch,
            train_loss[epoch - 1],
            train_accuracy[epoch - 1],
            val_loss[epoch - 1],
            val_accuracy[epoch - 1]
        ])

print(f"Training results saved to {output_file}")
# Out:
# Training results saved to mlp-2a.csv
